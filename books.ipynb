# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DataSets/books.csv", on_bad_lines='skip')

# %%
df
# Out:
#        bookID                                              title
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...  \
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating
# 0                             J.K. Rowling/Mary GrandPré            4.57  \
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count
# 0      0439785960  9780439785969           eng          652        2095690  \
# 1      0439358078  9780439358071           eng          870        2153167
# 2      0439554896  9780439554893           eng          352           6333
# 3      043965548X  9780439655484           eng          435        2339585
# 4      0439682584  9780439682589           eng         2690          41428
# ...           ...            ...           ...          ...            ...
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9/16/2006  Scholastic Inc.
# 1                   29221         9/1/2004  Scholastic Inc.
# 2                     244        11/1/2003       Scholastic
# 3                   36325         5/1/2004  Scholastic Inc.
# 4                     164        9/13/2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12/21/2004    Da Capo Press
# 11119                  56        12/1/1988    Penguin Books
# 11120                  95         8/1/1993    Penguin Books
# 11121                 139        2/27/2007             Ecco
# 11122                  12        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
df.dtypes
# Out:
# bookID                  int64
# title                  object
# authors                object
# average_rating        float64
# isbn                   object
# isbn13                  int64
# language_code          object
# num_pages               int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# dtype: object

# %%
df.shape
# Out:
# (11123, 12)

# %%
df.describe()
# Out:
#              bookID  average_rating        isbn13     num_pages
# count  11123.000000    11123.000000  1.112300e+04  11123.000000  \
# mean   21310.856963        3.934075  9.759880e+12    336.405556
# std    13094.727252        0.350485  4.429758e+11    241.152626
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10277.500000        3.770000  9.780345e+12    192.000000
# 50%    20287.000000        3.960000  9.780582e+12    299.000000
# 75%    32104.500000        4.140000  9.780872e+12    416.000000
# max    45641.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112300e+04        11123.000000
# mean    1.794285e+04          542.048099
# std     1.124992e+05         2576.619589
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           47.000000
# 75%     5.000500e+03          238.000000
# max     4.597666e+06        94265.000000

# %%
df.describe(include='object')
# Out:
#             title       authors        isbn language_code publication_date
# count       11123         11123       11123         11123            11123  \
# unique      10348          6639       11123            27             3679
# top     The Iliad  Stephen King  0439785960           eng        10/1/2005
# freq            9            40           1          8908               56
#
#        publisher
# count      11123
# unique      2290
# top      Vintage
# freq         318

# %%
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
# num_pages             0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7   num_pages           11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# Feature Engineering
#
# * Extract Important Features
# * Reducing the size of Features
# * Creating new features from the exissting ones

# %%
df.head()
# Out:
#    bookID                                              title
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...  \
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969  \
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code  num_pages  ratings_count  text_reviews_count
# 0           eng        652        2095690               27591  \
# 1           eng        870        2153167               29221
# 2           eng        352           6333                 244
# 3           eng        435        2339585               36325
# 4           eng       2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
df['isbn'].nunique()
# Out:
# 11123

# %%
df['isbn13'].nunique()
# Out:
# 11123

# %%
df.drop(columns=['isbn','bookID','isbn13'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                title
# 0  Harry Potter and the Half-Blood Prince (Harry ...  \
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating language_code  num_pages
# 0  J.K. Rowling/Mary GrandPré            4.57           eng        652  \
# 1  J.K. Rowling/Mary GrandPré            4.49           eng        870
# 2                J.K. Rowling            4.42           eng        352
# 3  J.K. Rowling/Mary GrandPré            4.56           eng        435
# 4  J.K. Rowling/Mary GrandPré            4.78           eng       2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591        9/16/2006  Scholastic Inc.
# 1        2153167               29221         9/1/2004  Scholastic Inc.
# 2           6333                 244        11/1/2003       Scholastic
# 3        2339585               36325         5/1/2004  Scholastic Inc.
# 4          41428                 164        9/13/2004       Scholastic

# %%
df['publication_date']
# Out:
# 0         9/16/2006
# 1          9/1/2004
# 2         11/1/2003
# 3          5/1/2004
# 4         9/13/2004
#             ...
# 11118    12/21/2004
# 11119     12/1/1988
# 11120      8/1/1993
# 11121     2/27/2007
# 11122     5/28/2006
# Name: publication_date, Length: 11123, dtype: object

# %%
df['year'] = df['publication_date'].str.split('/')

df ['year'] = df['year'].apply(lambda x:x[-1])

# %%
df['year']
# Out:
# 0        2006
# 1        2004
# 2        2003
# 3        2004
# 4        2004
#          ...
# 11118    2004
# 11119    1988
# 11120    1993
# 11121    2007
# 11122    2006
# Name: year, Length: 11123, dtype: object

# %%
df['year'] = df['year'].astype('int64')

# %%
df.dtypes
# Out:
# title                  object
# authors                object
# average_rating        float64
# language_code          object
# num_pages               int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# year                    int64
# dtype: object

# %%
df['year'].min()
# Out:
# 1900

# %%
df['year'].max()
# Out:
# 2020

# %% [markdown]
# EDA

# %%
df[df['year']==2019][['title','authors','average_rating','language_code','publisher']]
# Out:
#                                                    title
# 390                        Enthusiasm and Divine Madness  \
# 1070           The Wish Giver: Three Tales of Coven Tree
# 3981                                   The Art of Loving
# 10335  American Genesis: Captain John Smith and the F...
# 10769                                    Object Thinking
# 10823                                            Monster
#
#                                           authors  average_rating
# 390    Josef Pieper/Richard Winston/Clara Winston            4.50  \
# 1070                   Bill Brittain/Andrew Glass            3.83
# 3981      Erich Fromm/Peter D. Kramer/Rainer Funk            4.04
# 10335                            Alden T. Vaughan            3.43
# 10769                             David      West            3.99
# 10823                           Walter Dean Myers            3.72
#
#       language_code                         publisher
# 390             eng              St. Augustines Press
# 1070            eng                     HarperCollins
# 3981            eng  Harper Perennial Modern Classics
# 10335           eng                           Pearson
# 10769           eng                   Microsoft Press
# 10823           eng                           Amistad

# %%
df.groupby(['year'])['title'].agg('count').sort_values(ascending=False).head(20)
# Out:
# year
# 2006    1700
# 2005    1260
# 2004    1069
# 2003     931
# 2002     798
# 2001     656
# 2000     534
# 2007     518
# 1999     450
# 1998     396
# 1997     290
# 1996     250
# 1995     249
# 1994     220
# 1992     183
# 1993     165
# 1991     151
# 1989     118
# 1990     117
# 1987      88
# Name: title, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x = 'authors',data=df,order = df['authors'].value_counts().iloc[:10].index)
plt.title("Top 10 authors with maximum book publish")
plt.xticks(fontsize = 12)
plt.show()

# %%
df['language_code'].value_counts().head(20)
# Out:
# language_code
# eng      8908
# en-US    1408
# spa       218
# en-GB     214
# fre       144
# ger        99
# jpn        46
# mul        19
# zho        14
# grc        11
# por        10
# en-CA       7
# ita         5
# enm         3
# lat         3
# swe         2
# rus         2
# srp         1
# nl          1
# msa         1
# Name: count, dtype: int64

# %%
df.groupby(['language_code'])[['average_rating','ratings_count','text_reviews_count']].agg('mean').style.background_gradient(cmap='Wistia')
# Out:
# <style type="text/css">
# #T_bd057_row0_col0 {
#   background-color: #fe9000;
#   color: #f1f1f1;
# }
# #T_bd057_row0_col1, #T_bd057_row1_col1, #T_bd057_row13_col2, #T_bd057_row14_col1, #T_bd057_row18_col1, #T_bd057_row19_col1 {
#   background-color: #e4ff78;
#   color: #000000;
# }
# #T_bd057_row0_col2 {
#   background-color: #e7fd71;
#   color: #000000;
# }
# #T_bd057_row1_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_bd057_row1_col2, #T_bd057_row14_col2, #T_bd057_row16_col1 {
#   background-color: #e6fe74;
#   color: #000000;
# }
# #T_bd057_row2_col0 {
#   background-color: #fe9800;
#   color: #000000;
# }
# #T_bd057_row2_col1 {
#   background-color: #f8ee32;
#   color: #000000;
# }
# #T_bd057_row2_col2 {
#   background-color: #ffbd00;
#   color: #000000;
# }
# #T_bd057_row3_col0, #T_bd057_row4_col0, #T_bd057_row5_col0, #T_bd057_row19_col0, #T_bd057_row21_col0 {
#   background-color: #ff9b00;
#   color: #000000;
# }
# #T_bd057_row3_col1 {
#   background-color: #f0f54e;
#   color: #000000;
# }
# #T_bd057_row3_col2 {
#   background-color: #f5f03c;
#   color: #000000;
# }
# #T_bd057_row4_col1 {
#   background-color: #f7ef38;
#   color: #000000;
# }
# #T_bd057_row4_col2 {
#   background-color: #ffe81b;
#   color: #000000;
# }
# #T_bd057_row5_col1, #T_bd057_row5_col2, #T_bd057_row25_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_bd057_row6_col0 {
#   background-color: #ff9d00;
#   color: #000000;
# }
# #T_bd057_row6_col1, #T_bd057_row7_col1, #T_bd057_row12_col1 {
#   background-color: #f4f141;
#   color: #000000;
# }
# #T_bd057_row6_col2 {
#   background-color: #f2f348;
#   color: #000000;
# }
# #T_bd057_row7_col0, #T_bd057_row8_col0 {
#   background-color: #fe9a00;
#   color: #000000;
# }
# #T_bd057_row7_col2 {
#   background-color: #eff654;
#   color: #000000;
# }
# #T_bd057_row8_col1, #T_bd057_row15_col2 {
#   background-color: #e5fe77;
#   color: #000000;
# }
# #T_bd057_row8_col2, #T_bd057_row17_col2, #T_bd057_row18_col2 {
#   background-color: #e5fe75;
#   color: #000000;
# }
# #T_bd057_row9_col0, #T_bd057_row26_col0 {
#   background-color: #fd8d00;
#   color: #f1f1f1;
# }
# #T_bd057_row9_col1, #T_bd057_row9_col2, #T_bd057_row10_col1, #T_bd057_row10_col2, #T_bd057_row11_col1, #T_bd057_row11_col2, #T_bd057_row13_col1, #T_bd057_row15_col1, #T_bd057_row17_col1, #T_bd057_row22_col0, #T_bd057_row22_col1, #T_bd057_row22_col2, #T_bd057_row25_col1, #T_bd057_row25_col2, #T_bd057_row26_col1, #T_bd057_row26_col2 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_bd057_row10_col0 {
#   background-color: #ffa900;
#   color: #000000;
# }
# #T_bd057_row11_col0 {
#   background-color: #ffa100;
#   color: #000000;
# }
# #T_bd057_row12_col0 {
#   background-color: #fe9700;
#   color: #000000;
# }
# #T_bd057_row12_col2 {
#   background-color: #edf759;
#   color: #000000;
# }
# #T_bd057_row13_col0 {
#   background-color: #fe9200;
#   color: #000000;
# }
# #T_bd057_row14_col0 {
#   background-color: #fe9000;
#   color: #000000;
# }
# #T_bd057_row15_col0, #T_bd057_row16_col0 {
#   background-color: #fe9600;
#   color: #000000;
# }
# #T_bd057_row16_col2 {
#   background-color: #e7fc6f;
#   color: #000000;
# }
# #T_bd057_row17_col0 {
#   background-color: #fe9400;
#   color: #000000;
# }
# #T_bd057_row18_col0 {
#   background-color: #ffa300;
#   color: #000000;
# }
# #T_bd057_row19_col2 {
#   background-color: #e6fd72;
#   color: #000000;
# }
# #T_bd057_row20_col0 {
#   background-color: #fe9300;
#   color: #000000;
# }
# #T_bd057_row20_col1 {
#   background-color: #faec2a;
#   color: #000000;
# }
# #T_bd057_row20_col2 {
#   background-color: #f5f13f;
#   color: #000000;
# }
# #T_bd057_row21_col1 {
#   background-color: #fbeb27;
#   color: #000000;
# }
# #T_bd057_row21_col2 {
#   background-color: #f3f244;
#   color: #000000;
# }
# #T_bd057_row23_col0 {
#   background-color: #ffa700;
#   color: #000000;
# }
# #T_bd057_row23_col1 {
#   background-color: #f1f44b;
#   color: #000000;
# }
# #T_bd057_row23_col2 {
#   background-color: #fee91d;
#   color: #000000;
# }
# #T_bd057_row24_col0 {
#   background-color: #fd8e00;
#   color: #f1f1f1;
# }
# #T_bd057_row24_col1 {
#   background-color: #e9fb69;
#   color: #000000;
# }
# #T_bd057_row24_col2 {
#   background-color: #ebf962;
#   color: #000000;
# }
# </style>
# <table id="T_bd057">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd057_level0_col0" class="col_heading level0 col0" >average_rating</th>
#       <th id="T_bd057_level0_col1" class="col_heading level0 col1" >ratings_count</th>
#       <th id="T_bd057_level0_col2" class="col_heading level0 col2" >text_reviews_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >language_code</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd057_level0_row0" class="row_heading level0 row0" >ale</th>
#       <td id="T_bd057_row0_col0" class="data row0 col0" >4.360000</td>
#       <td id="T_bd057_row0_col1" class="data row0 col1" >102.000000</td>
#       <td id="T_bd057_row0_col2" class="data row0 col2" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row1" class="row_heading level0 row1" >ara</th>
#       <td id="T_bd057_row1_col0" class="data row1 col0" >3.550000</td>
#       <td id="T_bd057_row1_col1" class="data row1 col1" >122.000000</td>
#       <td id="T_bd057_row1_col2" class="data row1 col2" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row2" class="row_heading level0 row2" >en-CA</th>
#       <td id="T_bd057_row2_col0" class="data row2 col0" >4.025714</td>
#       <td id="T_bd057_row2_col1" class="data row2 col1" >4086.714286</td>
#       <td id="T_bd057_row2_col2" class="data row2 col2" >324.428571</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row3" class="row_heading level0 row3" >en-GB</th>
#       <td id="T_bd057_row3_col0" class="data row3 col0" >3.923411</td>
#       <td id="T_bd057_row3_col1" class="data row3 col1" >2463.691589</td>
#       <td id="T_bd057_row3_col2" class="data row3 col2" >104.060748</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row4" class="row_heading level0 row4" >en-US</th>
#       <td id="T_bd057_row4_col0" class="data row4 col0" >3.914659</td>
#       <td id="T_bd057_row4_col1" class="data row4 col1" >3773.906960</td>
#       <td id="T_bd057_row4_col2" class="data row4 col2" >160.357244</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row5" class="row_heading level0 row5" >eng</th>
#       <td id="T_bd057_row5_col0" class="data row5 col0" >3.934062</td>
#       <td id="T_bd057_row5_col1" class="data row5 col1" >21570.272564</td>
#       <td id="T_bd057_row5_col2" class="data row5 col2" >645.156601</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row6" class="row_heading level0 row6" >enm</th>
#       <td id="T_bd057_row6_col0" class="data row6 col0" >3.873333</td>
#       <td id="T_bd057_row6_col1" class="data row6 col1" >3233.666667</td>
#       <td id="T_bd057_row6_col2" class="data row6 col2" >84.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row7" class="row_heading level0 row7" >fre</th>
#       <td id="T_bd057_row7_col0" class="data row7 col0" >3.971528</td>
#       <td id="T_bd057_row7_col1" class="data row7 col1" >3277.319444</td>
#       <td id="T_bd057_row7_col2" class="data row7 col2" >64.513889</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row8" class="row_heading level0 row8" >ger</th>
#       <td id="T_bd057_row8_col0" class="data row8 col0" >3.950101</td>
#       <td id="T_bd057_row8_col1" class="data row8 col1" >234.727273</td>
#       <td id="T_bd057_row8_col2" class="data row8 col2" >8.232323</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row9" class="row_heading level0 row9" >gla</th>
#       <td id="T_bd057_row9_col0" class="data row9 col0" >4.470000</td>
#       <td id="T_bd057_row9_col1" class="data row9 col1" >11.000000</td>
#       <td id="T_bd057_row9_col2" class="data row9 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd057_level0_row10" class="row_heading level0 row10" >glg</th>
#       <td id="T_bd057_row10_col0" class="data row10 col0" >3.360000</td>
#       <td id="T_bd057_row10_col1" class="data row10 col1" >36.000000</td>
#       <td id="T_bd057_row10_col2" class="data row10 col2" >2.000000</td>
#     </tr>
#     <tr>
