# %%
import pandas as pd

# %%
df = pd.read_csv("DataSets/Untitled form.csv")

# %%
df.isnull().sum()
# Out:
# Timestamp                                                       0
# Username                                                        1
# Name :                                                          1
# Add payment slip or transaction ID                            159
# Designation :                                                   5
# College / Institution :                                         3
# Email.Id :                                                     10
# Contact No :                                                    5
# Abstract Title :                                               63
# How do want you attend                                         53
# join the WhatsApp group by clicking on the following link      50
# dtype: int64

# %%
df.shape
# Out:
# (250, 11)

# %%
x = df[['Name : ','College / Institution :','Designation :','Email.Id :',"Contact No :"]]

# %%
x.to_excel('final.xlsx')

# %%
df.drop_duplicates()
# Out:
#                            Timestamp                      Username  \
# 0    2023/02/21 12:04:10 PM GMT+5:30                           NaN
# 1    2023/02/21 12:59:37 PM GMT+5:30      ghouselecturer@gmail.com
# 2     2023/02/21 1:04:42 PM GMT+5:30      nenavath.balu1@gmail.com
# 3     2023/02/21 1:05:46 PM GMT+5:30  thejavathlaxman123@gmail.com
# 4     2023/02/21 1:20:03 PM GMT+5:30         drsharwanis@gmail.com
# ..                               ...                           ...
# 245  2023/03/12 12:27:31 PM GMT+5:30     srivallimadana9@gmail.com
# 246  2023/03/12 12:35:46 PM GMT+5:30     srivallimadana9@gmail.com
# 247  2023/03/12 12:39:32 PM GMT+5:30     gowthamiyadav74@gmail.com
# 248  2023/03/12 12:49:00 PM GMT+5:30  juveriyaprincess77@gmail.com
# 249   2023/03/12 3:58:03 PM GMT+5:30             kpjyodl@gmail.com
#
#                           Name :   \
# 0    Dr Chalamalla Venkateshwarlu
# 1             Dr۔ Mohammed Ghouse
# 2             Nenavath Balu naik
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Username', 'Name : ',
#        'Add payment slip or transaction ID ', 'Designation :',
#        'College / Institution :', 'Email.Id :', 'Contact No :',
#        'Abstract Title :', 'How do want you attend ',
#        'join the WhatsApp group by clicking on the following link '],
#       dtype='object')

# %%
df['Email.Id :'] = df['Email.Id :'].drop_duplicates()

# %%
df.columns
# Out:
# Index(['Timestamp', 'Username', 'Name : ',
#        'Add payment slip or transaction ID ', 'Designation :',
#        'College / Institution :', 'Email.Id :', 'Contact No :',
#        'Abstract Title :', 'How do want you attend ',
#        'join the WhatsApp group by clicking on the following link '],
#       dtype='object')

# %%
df
# Out:
#                            Timestamp                      Username  \
# 0    2023/02/21 12:04:10 PM GMT+5:30                           NaN
# 1    2023/02/21 12:59:37 PM GMT+5:30      ghouselecturer@gmail.com
# 2     2023/02/21 1:04:42 PM GMT+5:30      nenavath.balu1@gmail.com
# 3     2023/02/21 1:05:46 PM GMT+5:30  thejavathlaxman123@gmail.com
# 4     2023/02/21 1:20:03 PM GMT+5:30         drsharwanis@gmail.com
# ..                               ...                           ...
# 245  2023/03/12 12:27:31 PM GMT+5:30     srivallimadana9@gmail.com
# 246  2023/03/12 12:35:46 PM GMT+5:30     srivallimadana9@gmail.com
# 247  2023/03/12 12:39:32 PM GMT+5:30     gowthamiyadav74@gmail.com
# 248  2023/03/12 12:49:00 PM GMT+5:30  juveriyaprincess77@gmail.com
# 249   2023/03/12 3:58:03 PM GMT+5:30             kpjyodl@gmail.com
#
#                           Name :   \
# 0    Dr Chalamalla Venkateshwarlu
# 1             Dr۔ Mohammed Ghouse
# 2             Nenavath Balu naik
# ...

# %%
df.rename(columns={'Name : ':'Name'},inplace=True)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Username', 'Name', 'Add payment slip or transaction ID ',
#        'Designation :', 'College / Institution :', 'Email.Id :',
#        'Contact No :', 'Abstract Title :', 'How do want you attend ',
#        'join the WhatsApp group by clicking on the following link '],
#       dtype='object')
